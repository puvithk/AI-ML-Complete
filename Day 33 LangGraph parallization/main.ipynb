# %% [markdown]
# **Research Making using paralization systems**

# %% [markdown]
# **Get the questions(Deep research)**
#
# **Provides details about the question(Steps which it must follow)**
#
# **Ask questions to  confirm(Intruppt)**
#
# **Makes various research and adds to context**
#
# **Give to LLM to provide answers**
#
# **Returns the best result**

# %%
#Import all libraies
from langgraph.graph import StateGraph , START , END
from langchain_tavily import TavilyResearch
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
#Inizialize object
#Tavily search object
tavily_search = TavilyResearch()
#Wikipied object 
wikipedia_search = WikipediaAPIWrapper()

# %%
# Create LLM 
llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview"
)
