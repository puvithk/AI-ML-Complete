# %% [markdown]
# Simple chat bot

# %% [markdown]
# Chat bot with summarized memory with external db
#
# Create a LLM \
# Node START \
# Node - ChatNode (chats with the users )\
# Node - Summizier (summizeries the messagses )\
# Node - END\
# Edge -  Summizer or END
#
#
# STATE(Message state and summary)

# %%
#Import all the modules 
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import MessagesState  , StateGraph , START , END
from langchain.messages import HumanMessage , SystemMessage  , RemoveMessage
from langgraph.checkpoint.memory import MemorySaver
from langgraph.checkpoint.sqlite import SqliteSaver
import sqlite3
import os , getpass
from pprint import pprint
from dotenv import load_dotenv

# %%
connection = sqlite3.connect("chatbot.db" , check_same_thread=False)

# %%
def _set_env(var:str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

# %%
_set_env("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"] = 'true'
os.environ["LANGCHAIN_PROJECT"] = "langgraph-testing"

# %% [markdown]
# Create a LLM

# %%
load_dotenv()
llm = ChatGoogleGenerativeAI(
    model =  "gemini-3.5-flash"
)

# %% [markdown]
# Define a state

# %%
class State(MessagesState):
    summary :str

# %% [markdown]
# Chat functions

# %%
def call_model(state : State):
    "Returns the llm invoke method"
    #Get the summary is present 
    summary = state.get('summary' , "")
    if summary:
        #add a system prompt 
        summary_prompt =  f"This is the summary up to date : {summary}"
        messages = [SystemMessage(content=summary_prompt)] + state["messages"]
    else :
        messages = state['messages']
    #Invoke the llm model
    response = llm.invoke(messages)
    return {
        "messages" : [response]
    }

# %%
def summarize_messages(state:State):
    "Summarizes the complete messages"

    summary = state.get("summary" , "")
    #Check weather the summary is present 
    if summary :
        #Add sumamry and the intruction 
        summary_messages = (
            f"This is the summary till date : {summary}"
            "Extend the summary by adding details from the lastest messages"
        ) 
    else :
        summary_messages =  "Create a summary of the lastest messages"
    

    messages = state['messages'] + [HumanMessage(content=summary_messages)]
    #Get the response 
    response = llm.invoke(messages)
    #Delete the messages 
    delete_messages = [RemoveMessage(id=m.id) for m in state['messages'][:-2]]

    return {
        "summary" : response.content , 
        "messages" : delete_messages
    }

# %%
def summary_conditional_node(state : State):
    "Checks the conditon to summarize or to end the conversation"

    if len(state['messages']) > 6 :
        return "summarize_messages"
    return END

# %% [markdown]
# Create a Agent State

# %%
builder = StateGraph(State)
builder.add_node("summarize_messages",summarize_messages )
builder.add_node("chat_node" , call_model)


builder.add_edge(START , "chat_node")
builder.add_conditional_edges("chat_node" , summary_conditional_node , {"summarize_messages" :"summarize_messages" , 
                                                                        END : END})
builder.add_edge("summarize_messages" , END)

memory = SqliteSaver(connection)

agent = builder.compile(checkpointer=memory)

# %%
agent

# %%
config = {
    "configurable" : {
        "thread_id" : "1"
    }
}

# %%
response = agent.invoke({
    "messages" :HumanMessage("I am Puvith")} , config)

# %%
response

# %%
response = agent.invoke({
    "messages" : [HumanMessage("What is my name ")] 
} , config)

# %%
for i in response['messages'][:]:
    i.pretty_print()

# %%
messages = [HumanMessage(content="Hi, my name is Puvith Kumar."),

HumanMessage(content="I am working at Endava as a software engineer."),

HumanMessage(content="I love building AI applications using LangGraph and LangChain."),

HumanMessage(content="I created a project called SareeFusion for saree design automation."),

HumanMessage(content="I also worked on a classroom monitoring system using depth cameras."),

HumanMessage(content="My favorite programming language is Python."),

HumanMessage(content="I enjoy backend development using Spring Boot."),

HumanMessage(content="I am interested in Generative AI and agentic workflows.")]

# %%
agent.invoke({
    'messages' : messages
} , config)
# Out:
# {'messages': [HumanMessage(content='I am interested in Generative AI and agentic workflows.', additional_kwargs={}, response_metadata={}, id='43b52e6a-2c1c-487e-b8d9-f7c9106c73de'),
#   AIMessage(content=[{'type': 'text', 'text': "Hi Puvith! It is great to meet you. \n\nYou have an incredibly impressive and diverse set of skills. The combination of **Python** (for AI and machine learning) and **Spring Boot** (for robust backend development) is highly valuable, especially when bridging the gap between cutting-edge AI research and production-grade software engineering.\n\nI'd love to hear more about your work! A few things in your intro really caught my attention:\n\n1. **SareeFusion:** This sounds like a fascinating and highly creative project. How does it work? Are you using diffusion models (like Stable Diffusion or ControlNet) to generate and automate the designs, or is it powered by another generative approach?\n2. **LangGraph & Agentic Workflows:** LangGraph is fantastic for building cyclic, stateful multi-agent systems. What kind of agentic workflows have you been designing lately? Are you building autonomous coding assistants, research agents, or something else?\n3. **Classroom Monitoring System:** Using depth cameras is a smart move, especially for privacy-preserving computer vision. What was the main use case there? Tracking student engagement, attendance, or something else?\n\nWelcome! Let me know what you'd like to chat about today—whether you want to brain-storm some LangGraph patterns, debug some Python/Spring Boot code, or just talk tech.", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e4927-1724-7490-95ca-2a234471d09f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 93, 'output_tokens': 883, 'total_tokens': 976, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 600}})],
#  'summary': [{'type': 'text',
#    'text': 'Here is a summary of our conversation so far:\n\n* **Your Profile:** Your name is **Puvith Kumar**, and you work as a **Software Engineer at Endava**.\n* **Technical Stack & Interests:** Your favorite programming language is **Python**, and you enjoy backend development using **Spring Boot**. You are highly interested in **Generative AI** and **agentic workflows**, specifically using **LangChain** and **LangGraph** to build AI applications.\n* **Key Projects:**\n  * **SareeFusion:** A project you created for automating saree designs.\n  * **Classroom Monitoring System:** A project you developed using depth cameras.\n* **My Response:** I welcomed you, noted how powerful your combined stack (Python/AI + Spring Boot backend) is, and asked for more details regarding the AI techniques behind *SareeFusion*, your experiences building agentic workflows with LangGraph, and the implementation of your classroom monitoring system.',
#    'extras': {'signature': '...'}}]}

# %%
response = agent.invoke({ 
    "messages":
                         [HumanMessage(content="Where do I work?")] } , config)

# %%
response
# Out:
# {'messages': [HumanMessage(content='I am interested in Generative AI and agentic workflows.', additional_kwargs={}, response_metadata={}, id='43b52e6a-2c1c-487e-b8d9-f7c9106c73de'),
#   AIMessage(content=[{'type': 'text', 'text': "Hi Puvith! It is great to meet you. \n\nYou have an incredibly impressive and diverse set of skills. The combination of **Python** (for AI and machine learning) and **Spring Boot** (for robust backend development) is highly valuable, especially when bridging the gap between cutting-edge AI research and production-grade software engineering.\n\nI'd love to hear more about your work! A few things in your intro really caught my attention:\n\n1. **SareeFusion:** This sounds like a fascinating and highly creative project. How does it work? Are you using diffusion models (like Stable Diffusion or ControlNet) to generate and automate the designs, or is it powered by another generative approach?\n2. **LangGraph & Agentic Workflows:** LangGraph is fantastic for building cyclic, stateful multi-agent systems. What kind of agentic workflows have you been designing lately? Are you building autonomous coding assistants, research agents, or something else?\n3. **Classroom Monitoring System:** Using depth cameras is a smart move, especially for privacy-preserving computer vision. What was the main use case there? Tracking student engagement, attendance, or something else?\n\nWelcome! Let me know what you'd like to chat about today—whether you want to brain-storm some LangGraph patterns, debug some Python/Spring Boot code, or just talk tech.", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e4927-1724-7490-95ca-2a234471d09f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 93, 'output_tokens': 883, 'total_tokens': 976, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 600}}),
#   HumanMessage(content='Where do I work?', additional_kwargs={}, response_metadata={}, id='6106f52b-c867-4971-8744-f5fff23c1b69'),
#   AIMessage(content=[{'type': 'text', 'text': 'You work as a Software Engineer at **Endava**!', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019e4927-748f-7552-94d1-e3161b3cf071-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2546, 'output_tokens': 117, 'total_tokens': 2663, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 105}})],
#  'summary': [{'type': 'text',
#    'text': 'Here is a summary of our conversation so far:\n\n* **Your Profile:** Your name is **Puvith Kumar**, and you work as a **Software Engineer at Endava**.\n* **Technical Stack & Interests:** Your favorite programming language is **Python**, and you enjoy backend development using **Spring Boot**. You are highly interested in **Generative AI** and **agentic workflows**, specifically using **LangChain** and **LangGraph** to build AI applications.\n* **Key Projects:**\n  * **SareeFusion:** A project you created for automating saree designs.\n  * **Classroom Monitoring System:** A project you developed using depth cameras.\n* **My Response:** I welcomed you, noted how powerful your combined stack (Python/AI + Spring Boot backend) is, and asked for more details regarding the AI techniques behind *SareeFusion*, your experiences building agentic workflows with LangGraph, and the implementation of your classroom monitoring system.',
#    'extras': {'signature': '...'}}]}

# %%
for i in response['messages'][:]:
    i.pretty_print()
# Out:
# ================================ Human Message =================================
#
# I am interested in Generative AI and agentic workflows.
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': "Hi Puvith! It is great to meet you. \n\nYou have an incredibly impressive and diverse set of skills. The combination of **Python** (for AI and machine learning) and **Spring Boot** (for robust backend development) is highly valuable, especially when bridging the gap between cutting-edge AI research and production-grade software engineering.\n\nI'd love to hear more about your work! A few things in your intro really caught my attention:\n\n1. **SareeFusion:** This sounds like a fascinating and highly creative project. How does it work? Are you using diffusion models (like Stable Diffusion or ControlNet) to generate and automate the designs, or is it powered by another generative approach?\n2. **LangGraph & Agentic Workflows:** LangGraph is fantastic for building cyclic, stateful multi-agent systems. What kind of agentic workflows have you been designing lately? Are you building autonomous coding assistants, research agents, or something else?\n3. **Classroom Monitoring System:** Using depth cameras is a smart move, especially for privacy-preserving computer vision. What was the main use case there? Tracking student engagement, attendance, or something else?\n\nWelcome! Let me know what you'd like to chat about today—whether you want to brain-storm some LangGraph patterns, debug some Python/Spring Boot code, or just talk tech.", 'extras': {'signature': '...'}}]
# ================================ Human Message =================================
#
# Where do I work?
# ================================== Ai Message ==================================
#
# [{'type': 'text', 'text': 'You work as a Software Engineer at **Endava**!', 'extras': {'signature': '...'}}]
